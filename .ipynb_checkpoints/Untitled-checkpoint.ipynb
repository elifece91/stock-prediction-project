# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-1.5.1-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pandas>=1.3.0 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from yfinance) (2.2.5)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from yfinance) (2.34.2)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.13-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from yfinance) (4.9.4)
# Requirement already satisfied: pytz>=2022.5 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from yfinance) (2026.2)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-4.1.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from yfinance) (4.15.0)
# Collecting curl_cffi>=0.15 (from yfinance)
#   Downloading curl_cffi-0.15.0-cp310-abi3-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Downloading protobuf-7.35.1-cp310-abi3-macosx_10_9_universal2.whl.metadata (595 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-16.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from curl_cffi>=0.15->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from curl_cffi>=0.15->yfinance) (2026.6.17)
# Collecting rich (from curl_cffi>=0.15->yfinance)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2026.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.7.0)
# Collecting markdown-it-py>=2.2.0 (from rich->curl_cffi>=0.15->yfinance)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/ml_projesi/lib/python3.10/site-packages (from rich->curl_cffi>=0.15->yfinance) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading yfinance-1.5.1-py2.py3-none-any.whl (144 kB)
# Downloading curl_cffi-0.15.0-cp310-abi3-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 12.2 MB/s  0:00:00 11.6 MB/s eta 0:00:01
# Downloading multitasking-0.0.13-py3-none-any.whl (16 kB)
# Downloading peewee-4.1.1-py3-none-any.whl (170 kB)
# Downloading protobuf-7.35.1-cp310-abi3-macosx_10_9_universal2.whl (433 kB)
# Downloading websockets-16.0-cp310-cp310-macosx_11_0_arm64.whl (175 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: peewee, multitasking, websockets, protobuf, mdurl, markdown-it-py, rich, curl_cffi, yfinance
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [yfinance];237m━━━━ 8/9 [yfinance]s]
# Successfully installed curl_cffi-0.15.0 markdown-it-py-4.2.0 mdurl-0.1.2 multitasking-0.0.13 peewee-4.1.1 protobuf-7.35.1 rich-15.0.0 websockets-16.0 yfinance-1.5.1

# %%
import yfinance as yf
import pandas as pd

# Apple'ın (AAPL) verilerini internetten canlı olarak çekiyoruz
df = yf.download("AAPL", start="2021-01-01", end="2026-07-01")

# İlk 5 satırını ekrana basıp kontrol ediyoruz
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2021-01-04  125.740829  129.821744  123.165964  129.734299  143301900
# 2021-01-05  127.295456  128.004769  124.788605  125.235569   97664900
# 2021-01-06  123.010513  127.334347  122.796750  124.098761  155088000
# 2021-01-07  127.208046  127.897922  124.234808  124.720632  109578200
# 2021-01-08  128.306046  128.869603  126.537640  128.675261  105158200

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker         AAPL         AAPL         AAPL         AAPL          AAPL
# count   1378.000000  1378.000000  1378.000000  1378.000000  1.378000e+03
# mean     187.582422   189.467431   185.555416   187.421332  6.809678e+07
# std       46.978765    47.389655    46.599252    46.971351  3.002873e+07
# min      113.229790   117.161125   113.083823   115.827969  1.791060e+07
# 25%      147.673874   148.806784   145.614606   147.005572  4.691572e+07
# 50%      175.703918   177.415391   174.142561   175.448486  6.040765e+07
# 75%      224.179485   225.588866   221.536797   223.436879  8.218822e+07
# max      315.200012   317.399994   309.649994   314.179993  3.186799e+08

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   AAPL      0
# High    AAPL      0
# Low     AAPL      0
# Open    AAPL      0
# Volume  AAPL      0
# dtype: int64

# %%
# Sadece kapanış fiyatı (Close) 180 dolardan büyük olan günleri filtreliyoruz
yuksek_gunler = df[df[('Close', 'AAPL')] > 180]

# Filtrelenmiş yeni tablonun ilk 5 satırına bakıyoruz
yuksek_gunler.head()
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2023-06-12  181.249008  181.347632  178.468004  178.763859   54274900
# 2023-06-13  180.775681  181.604064  179.917713  180.272737   54929100
# 2023-06-14  181.406830  181.840749  179.503520  180.834847   57462900
# 2023-06-15  183.438324  183.941283  181.239159  181.416678   65433200
# 2023-06-16  182.363388  184.404777  181.722381  184.148362  101256200
